# %% [markdown]
# <a href="https://colab.research.google.com/github/RaziehAkbari2020/heart-attack/blob/main/Heart_data_Cleansing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Steps on Analyzing Heart data:

# %% [markdown]
# ## Step 1: EDA (To review the dada generally)

# %%
# !pip install dataprep

# %%
pip install -U dataprep
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting dataprep
#   Using cached dataprep-0.4.1-py3-none-any.whl (3.5 MB)
# ...
#      ---------------------------------------- 0.0/18.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/18.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/18.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/18.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/18.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/18.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/18.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/18.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/18.5 MB 59.5 kB/s eta 0:05:11
#      ---------------------------------------- 0.0/18.5 MB 59.5 kB/s eta 0:05:11
#      ---------------------------------------- 0.0/18.5 MB 59.5 kB/s eta 0:05:11
# ...

# %%
pip install dtale
# Out:
# ...
#   Obtaining dependency information for dtale from https://files.pythonhosted.org/packages/87/d2/d1695b8eabca8d0215f238b0337acab1ed5d57e5f0644c056c6a68ad169d/dtale-3.7.0-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/62.3 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.3 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/62.3 kB ? eta -:--:--
#      ------------------ ------------------- 30.7/62.3 kB 262.6 kB/s eta 0:00:01
#      ------------------------ ------------- 41.0/62.3 kB 281.8 kB/s eta 0:00:01
#      -------------------------------------- 62.3/62.3 kB 303.0 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/642.7 kB ? eta -:--:--
#      - ----------------------------------- 30.7/642.7 kB 640.0 kB/s eta 0:00:01
# ...

# %%
import pandas as pd
import dtale
df=pd.read_csv('C:/Users/Razieh Akbari/Desktop/Python/heart.csv')
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://TABLET-1E2ECRU2:40000/dtale/iframe/3"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# 2023-10-17 18:49:21,192 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-17 18:49:21,197 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-17 18:49:21,197 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-17 18:49:21,208 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-17 18:49:21,208 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-17 18:49:21,212 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-17 18:49:21,212 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-17 18:49:21,212 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-10-17 18:49:21,219 - WARNING  - findfont: Font family 'Heiti TC' not found.
# ...
